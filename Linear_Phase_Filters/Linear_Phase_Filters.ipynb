# %%
from Linear_Phase_Filters_utils import *

# %matplotlib widget

# %% [markdown]
# # Loading the sound

# %%
lpf = LPF()
# Out:
# Sampling frequency = 16000 Hz
# Number of samples = 32768

# %% [markdown]
# # Exploring the sound wave and frequency spectrum

# %%
lpf.explore_signal()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Removing the phase information
#
# As demonstrated in the cell below, the phase information of a signal is important to determine the shape and timing of the sound wave. If we completely remove the phase information (by applying the absolute value to the Fourier Transform and restoring the sound from that), we completely loose the sharp start of the tone, but keep the same pitch.

# %%
lpf.remove_phase()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# ...

# %% [markdown]
# # Modifying the phase
#
# Modifying the phase of the signal will change the timing information slightly, introducing strange artefacts.

# %%
lpf.modify_phase()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# ...

# %% [markdown]
# # Exercise

# %%
plt.close('all')
ex = LinearPhaseFilterExercise()
